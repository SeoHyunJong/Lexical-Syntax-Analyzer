# %%
import sys #input 파일 받아올때 필요

# %%
action = {(0,'vtype'):'s5', (0, 'class'):'s6', (0, '$'):'r4', #action table
          (1, '$'):'acc',
          (2, 'vtype'):'s5', (2, 'class'):'s6', (2, '$'):'r4',
          (3, 'vtype'):'s5', (3, 'class'):'s6', (3, '$'):'r4',
          (4, 'vtype'):'s5', (4, 'class'):'s6', (4, '$'):'r4',
          (5, 'id'):'s10',
          (6, 'id'):'s12',
          (7, '$'):'r1',
          (8, '$'):'r2',
          (9, '$'):'r3',
          (10, 'semi'):'s13', (10, 'assign'):'s15', (10, 'lparen'):'s14',
          (13, 'vtype'): 'r5', (14, 'vtype'): 's19', (16, 'vtype'): 'r6',
          (17, 'vtype'): 's5', (31, 'vtype'): 's5', (32, 'vtype'): 's5',
          (38, 'vtype'): 'r35', (41, 'vtype'): 's53', (43, 'vtype'): 's55',
          (48, 'vtype'): 's53', (49, 'vtype'): 'r26', (59, 'vtype'): 'r27',
          (64, 'vtype'): 'r19', (74, 'vtype'): 's53', (76, 'vtype'): 's53',
          (79, 'vtype'): 'r33', (80, 'vtype'): 'r29', (81, 'vtype'): 'r28',
          (83, 'vtype'): 's53', (85, 'vtype'): 'r32',
          (13, 'id'): 'r5', (15, 'id'): 's28', (16, 'id'): 'r6', (19, 'id'): 's34',
          (27, 'id'): 's28', (35, 'id'): 's28', (36, 'id'): 's28', (41, 'id'): 's54',
          (48, 'id'): 's54', (49, 'id'): 'r26', (53, 'id'): 's62', (55, 'id'): 's63',
          (57, 'id'): 's28', (59, 'id'): 'r27', (74, 'id'): 's54', (76, 'id'): 's54',
          (79, 'id'): 'r33', (80, 'id'): 'r29', (81, 'id'): 'r28', (83, 'id'): 's54',
          (85, 'id'): 'r32',
          (11, 'semi'): 's16', (20, 'semi'): 'r7', (21, 'semi'): 'r8', (22, 'semi'): 'r9',
          (23, 'semi'): 'r10', (24, 'semi'): 'r11', (25, 'semi'): 'r13', (26, 'semi'): 'r15',
          (28, 'semi'): 'r17', (29, 'semi'): 'r18', (44, 'semi'): 'r12', (45, 'semi'): 'r14',
          (46, 'semi'): 'r16', (50, 'semi'): 's59', (62, 'semi'): 's13', (65, 'semi'): 's70',
          (54, 'assign'): 's15', (62, 'assign'): 's15',
          (15, 'literal'): 's22', (57, 'literal'): 's22',
          (15, 'character'): 's23', (57, 'character'): 's23',
          (15, 'boolstr'): 's24', (57, 'boolstr'): 's24', (60, 'boolstr'): 's67', (61, 'boolstr'): 's67',
          (72, 'boolstr'): 's67',
          (25, 'addsub'): 's35', (26, 'addsub'): 'r15', (28, 'addsub'): 'r17', (29, 'addsub'): 'r18',
          (45, 'addsub'): 'r14', (46, 'addsub'): 'r16',
          (26, 'multdiv'): 's36', (28, 'multdiv'): 'r17', (29, 'multdiv'): 'r18', (46, 'multdiv'): 'r16',
          (15, 'lparen'): 's27', (27, 'lparen'): 's27', (35, 'lparen'): 's27',
          (36, 'lparen'): 's27', (51, 'lparen'): 's60', (52, 'lparen'): 's61', (57, 'lparen'): 's27',
          (14, 'rparen'): 'r21', (18, 'rparen'): 's33', (25, 'rparen'): 'r13', (26, 'rparen'): 'r15',
          (28, 'rparen'): 'r17', (29, 'rparen'): 'r18', (34, 'rparen'): 'r23', (37, 'rparen'): 's46',
          (42, 'rparen'): 'r20', (44, 'rparen'): 'r12', (45, 'rparen'): 'r14', (46, 'rparen'): 'r16',
          (63, 'rparen'): 'r23', (66, 'rparen'): 's71', (67, 'rparen'): 'r31', (68, 'rparen'): 's73',
          (69, 'rparen'): 'r22', (75, 'rparen'): 'r30',
          (15, 'num'): 's29', (27, 'num'): 's29', (35, 'num'): 's29', (36, 'num'): 's29',
          (57, 'num'): 's29',
          (12, 'lbrace'): 's17', (33, 'lbrace'): 's41', (71, 'lbrace'): 's74',
          (73, 'lbrace'): 's76', (82, 'lbrace'): 's83',
          (13, 'rbrace'): 'r5', (16, 'rbrace'): 'r6', (17, 'rbrace'): 'r38', (30, 'rbrace'): 's38',
          (31, 'rbrace'): 'r38', (32, 'rbrace'): 'r38', (39, 'rbrace'): 'r36', (40, 'rbrace'): 'r37',
          (41, 'rbrace'): 'r25', (48, 'rbrace'): 'r25', (49, 'rbrace'): 'r26', (56, 'rbrace'): 's64',
          (58, 'rbrace'): 'r24', (59, 'rbrace'): 'r27', (64, 'rbrace'): 'r19', (70, 'rbrace'): 'r34',
          (74, 'rbrace'): 'r25', (76, 'rbrace'): 'r25', (77, 'rbrace'): 's79', (78, 'rbrace'): 's80',
          (79, 'rbrace'): 'r33', (80, 'rbrace'): 'r29', (81, 'rbrace'): 'r28', (83, 'rbrace'): 'r25',
          (84, 'rbrace'): 's85', (85, 'rbrace'): 'r32',
          (34, 'comma'): 's43', (63, 'comma'): 's43',
          (13, 'if'): 'r5', (16, 'if'): 'r6', (41, 'if'): 's51', (48, 'if'): 's51',
          (49, 'if'): 'r26', (59, 'if'): 'r27', (74, 'if'): 's51', (76, 'if'): 's51',
          (79, 'if'): 'r33', (80, 'if'): 'r29', (81, 'if'): 'r28', (83, 'if'): 's51',
          (85, 'if'): 'r32',
          (13, 'while'): 'r5', (16, 'while'): 'r6', (41, 'while'): 's52', (48, 'while'): 's52',
          (49, 'while'): 'r26', (59, 'while'): 'r27', (74, 'while'): 's52', (76, 'while'): 's52',
          (79, 'while'): 'r33', (80, 'while'): 'r29', (81, 'while'): 'r28', (83, 'while'): 's52',
          (85, 'while'): 'r32',
          (67, 'comp'): 's72',
          (79, 'else'): 's82',
          (13, 'return'): 'r5', (16, 'return'): 'r6', (41, 'return'): 'r25', (47, 'return'): 's57',
          (48, 'return'): 'r25', (49, 'return'): 'r26', (58, 'return'): 'r24', (59, 'return'): 'r27',
          (74, 'return'): 'r25', (76, 'return'): 'r25', (79, 'return'): 'r33', (80, 'return'): 'r29',
          (81, 'return'): 'r28', (83, 'return'): 'r25', (85, 'return'): 'r32',
          (13, 'class'): 'r5', (16, 'class'): 'r6', (38, 'class'): 'r35', (64, 'class'): 'r19',
          (13, '$'): 'r5', (16, '$'): 'r6', (38, '$'): 'r35', (64, '$'): 'r19'}

goto = {(0,'CODE'): 1, (2,'CODE'): 7, (3,'CODE'): 8, (4,'CODE'): 9, # goto table
        (0, 'VDECL'): 2, (2, 'VDECL'): 2, (3, 'VDECL'): 2, (4, 'VDECL'): 2,
        (17, 'VDECL'): 31, (31, 'VDECL'): 31, (32, 'VDECL'): 31, (41, 'VDECL'): 49,
        (48, 'VDECL'): 49, (74, 'VDECL'): 49, (76, 'VDECL'): 49, (83, 'VDECL'): 49,
        (5, 'ASSIGN'): 11, (41, 'ASSIGN'): 50, (48, 'ASSIGN'): 50, (53, 'ASSIGN'): 11,
        (74, 'ASSIGN'): 50, (76, 'ASSIGN'): 50, (83, 'ASSIGN'): 50,
        (15, 'RHS'): 20, (57, 'RHS'): 65,
        (15, 'EXPR'): 21, (27, 'EXPR'): 37, (35, 'EXPR'): 44, (57, 'EXPR'): 21,
        (15, 'T'): 25, (27, 'T'): 25, (35, 'T'): 25, (36, 'T'): 45, (57, 'T'): 25,
        (15, 'F'): 26, (27, 'F'): 26, (35, 'F'): 26, (36, 'F'): 26, (57, 'F'): 26,
        (0, 'FDECL'): 3, (2, 'FDECL'): 3, (3, 'FDECL'): 3, (4, 'FDECL'): 3,
        (17, 'FDECL'): 32, (31, 'FDECL'): 32, (32, 'FDECL'): 32,
        (14, 'ARG'): 18,
        (34, 'MOREARGS'): 42, (63, 'MOREARGS'): 69,
        (41, 'BLOCK'): 47, (48, 'BLOCK'): 58, (74, 'BLOCK'): 77, (76, 'BLOCK'): 78, (83, 'BLOCK'): 84,
        (41, 'STMT'): 48, (48, 'STMT'): 48, (74, 'STMT'): 48, (76, 'STMT'): 48, (83, 'STMT'): 48,
        (60, 'COND'): 66, (61, 'COND'): 68, (72, 'COND'): 75,
        (79, 'ELSE'): 81,
        (47, 'RETURN'): 56,
        (0, 'CDECL'): 4, (2, 'CDECL'): 4, (3, 'CDECL'): 4, (4, 'CDECL'): 4,
        (17, 'ODECL'): 30, (31, 'ODECL'): 39, (32, 'ODECL'): 40}

reduction = [['S', 1], # reduction에 필요한 테이블. 각 요소의 두번째 요소는 pop 시에 필요한 length를 의미한다.
             ['CODE', 2],
             ['CODE', 2],
             ['CODE', 2],
             ['CODE', 0],
             ['VDECL', 3],
             ['VDECL', 3],
             ['ASSIGN', 3],
             ['RHS', 1],
             ['RHS', 1],
             ['RHS', 1],
             ['RHS', 1],
             ['EXPR', 3],
             ['EXPR', 1],
             ['T', 3],
             ['T', 1],
             ['F', 3],
             ['F', 1],
             ['F', 1],
             ['FDECL', 9],
             ['ARG', 3],
             ['ARG', 0],
             ['MOREARGS', 4],
             ['MOREARGS', 0],
             ['BLOCK', 2],
             ['BLOCK', 0],
             ['STMT', 1],
             ['STMT', 2],
             ['STMT', 8],
             ['STMT', 7],
             ['COND', 3],
             ['COND', 1],
             ['ELSE', 4],
             ['ELSE', 0],
             ['RETURN', 3],
             ['CDECL', 5],
             ['ODECL', 2],
             ['ODECL', 2],
             ['ODECL', 0]]

token = {'INT':'vtype', 'CHAR':'vtype', 'BOOL':'vtype', 'STRING':'vtype', # lexical analyzer에서 나온 토큰을 terminal로 rename.
         'INTEGER':'num', 'CHARACTER':'character', 'BOOLEAN':'boolstr',
         'LITERAL':'literal', 'ID':'id', 'IF':'if', 'ELSE':'else',
         'WHILE':'while', 'RETURN':'return', 'CLASS':'class', 'ADD':'addsub',
         'SUB':'addsub', 'MUL':'multdiv', 'DIV':'multdiv', 'ASSIGN':'assign',
         'COMPARISON':'comp', 'SEMI':'semi', 'COMMA':'comma',
         'LBRACE':'lbrace', 'RBRACE':'rbrace', 'LPAREN':'lparen', 'RPAREN':'rparen'}

# %%
f = open("MyClass_output.txt", 'r')
lines = f.readlines()
f.close()

# %%
# ==== lexical analyzer에서 나온 토큰 리스트들을 terminal로 변환하는 작업 ====
refine = []
for i in lines:
    idx = i.find(" ")
    if idx != -1:
        refine.append(token[i[:idx]])
    else:
        idx = i.find("\\")
        refine.append(token[i[:idx]])
# ============================================================================
refine.append('$') # 리스트 끝에 $를 추가한다.
stack = [0,] # 스택을 생성한다. start state가 포함된채로 선언
next_sym = refine[0] # 초기 next sym 또한 첫번째 리스트 요소로 초기화
cur = 0 # next symbol을 움직이는, 즉 shift 연산에 필요한 변수

for i in range(1000): # 무한 루프로 해도 무방하다.
    top = stack[-1] # 스택의 탑을 가져온다.
    
    if (top, next_sym) not in action: # error 발생시 오류 호출
        print("액션테이블에서 ({0},{1})은 존재하지 않습니다.".format(top, next_sym))
        print("output 파일에서 {0}줄에 오류가 있습니다.".format(cur+1))
        break;
    
    act = action[(top, next_sym)] # 액션 테이블에서 취할 액션을 가져온다.
    if act[0] == 's': # shift
        stack.append(int(act[1:])) # 스택에 push
        cur = cur + 1 # next symbol을 다음것으로 옮기기, 즉 shift.
        next_sym = refine[cur]
        print(stack)
    elif act[0] == 'r': # reduction
        count = reduction[int(act[1:])][1] # 스택에서 얼만큼 pop할지 결정한다.
        state = reduction[int(act[1:])][0] # goto 액션에 필요한 nonterminal을 가져온다.
        if count > 0:
            for i in range(count):
                stack.pop() # 스택에서 pop
        top = stack[-1] # 스택의 top을 업데이트
        
        if (top, state) not in goto: # error 발생시 오류 호출
            print("goto 테이블에서 ({0},{1})은 존재하지 않습니다.".format(top, state))
            print("output 파일에서 {0}줄에 오류가 있습니다.".format(cur+1))
            break;
        
        stack.append(goto[(top, state)]) # goto 액션에서 나온 state를 push 한다.
        print(stack)
    elif act == 'acc': # 축하합니다! 성공하셨습니다!
        print("accept!")
        break # 루프에서 빠져나오기.
# Out:
# [0, 6]
# [0, 6, 12]
# [0, 6, 12, 17]
# [0, 6, 12, 17, 5]
# [0, 6, 12, 17, 5, 10]
# [0, 6, 12, 17, 5, 10, 14]
# [0, 6, 12, 17, 5, 10, 14, 18]
# [0, 6, 12, 17, 5, 10, 14, 18, 33]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 62]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 62, 15]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 62, 15, 29]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 62, 15, 26]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 62, 15, 25]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 62, 15, 21]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 62, 15, 20]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 11]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 53, 11, 16]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 49]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 48]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 48, 53]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 48, 53, 62]
# [0, 6, 12, 17, 5, 10, 14, 18, 33, 41, 48, 53, 62, 15]
# ...
